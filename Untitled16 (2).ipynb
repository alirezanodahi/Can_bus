# %%
#library
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import random


from collections import Counter

# %matplotlib inline

# %%
df4 = pd.read_csv('/content/drive/MyDrive/datasets/ML_350/ML350_Dataset.csv',sep=',')

df5 = df4.drop(['Flag'], axis=1)

# %%
df4
#date frame
# Out:
#         CAN Identifier   D0   D1   D2   D3   D4  D5   D6   D7 Flag
# 0                  768  128  141  128    0  128   0  127  204    R
# 1                  885    0    0    0    0    0   0    0    0    T
# 2                 1023    0    0    0    0    0   0    0    0    T
# 3                  768  128  136  128    0  128   0  127  255    R
# 4                  520  159  144  221  178  159  21  186  147    T
# ...                ...  ...  ...  ...  ...  ...  ..  ...  ...  ...
# 730514             768  227  118   48  187  220  18  186  136    T
# 730515             768  128  136  128    0  128   0  127  221    R
# 730516             768  128  136  128    0  128   0  127  221    R
# 730517             768  128  136  128    0  128   0  127   84    R
# 730518             520    0   32    0    2    0   0    0    0    R
#
# [730519 rows x 10 columns]

# %%
#training
from sklearn.ensemble import IsolationForest
import itertools
model=IsolationForest(n_estimators=140, max_samples=0.8, contamination=float(0.4), max_features=0.9)

model.fit(df5)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.4, max_features=0.9, max_samples=0.8,
#                 n_estimators=140)

# %%
df5['anomaly']=model.predict(df5)


df5.head(10)
df5= df5.join(df4['Flag'])

# %%
df5
# anomaly for the predict and flag is main lable
# Out:
#         CAN Identifier   D0   D1   D2   D3   D4  D5   D6   D7  anomaly Flag
# 0                  768  128  141  128    0  128   0  127  204        1    R
# 1                  885    0    0    0    0    0   0    0    0        1    T
# 2                 1023    0    0    0    0    0   0    0    0       -1    T
# 3                  768  128  136  128    0  128   0  127  255        1    R
# 4                  520  159  144  221  178  159  21  186  147       -1    T
# ...                ...  ...  ...  ...  ...  ...  ..  ...  ...      ...  ...
# 730514             768  227  118   48  187  220  18  186  136       -1    T
# 730515             768  128  136  128    0  128   0  127  221        1    R
# 730516             768  128  136  128    0  128   0  127  221        1    R
# 730517             768  128  136  128    0  128   0  127   84        1    R
# 730518             520    0   32    0    2    0   0    0    0        1    R
#
# [690519 rows x 11 columns]

# %%
df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "R" )].reset_index()
# Out:
#          index  CAN Identifier   D0   D1   D2  D3   D4  D5   D6   D7  anomaly  \
# 0            0             768  128  141  128   0  128   0  127  204        1
# 1            3             768  128  136  128   0  128   0  127  255        1
# 2            7             520    0   32    0   0    0   0    0    0        1
# 3            8             768  128  136  128   0  128   0  127  187        1
# 4           11             520    0   32    0   0    0   0    0    0        1
# ...        ...             ...  ...  ...  ...  ..  ...  ..  ...  ...      ...
# 305781  730511             520    0   32    0   0   71   1   71    3        1
# 305782  730515             768  128  136  128   0  128   0  127  221        1
# 305783  730516             768  128  136  128   0  128   0  127  221        1
# 305784  730517             768  128  136  128   0  128   0  127   84        1
# 305785  730518             520    0   32    0   2    0   0    0    0        1
#
#        Flag
# 0         R
# ...

# %%
df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "R" )].reset_index()

# %%
anomaly = df5.loc[df5['anomaly']==-1]
anomaly_index = list(anomaly.index)
print('Total number of outliers is:', len(anomaly))
# Out:
# Total number of outliers is: 344733

# %%
df5[df5['anomaly']==-1]#73052 for es=150 and for(357083)
# Out:
#         CAN Identifier   D0   D1   D2   D3   D4   D5   D6   D7  anomaly Flag
# 4                  520  159  144  221  178  159   21  186  147       -1    T
# 5                  520  227  108   91   25  223  185  232  207       -1    T
# 9                  520  223  117  170  205   10   20   95   38       -1    T
# 10                1023  122  116  235    6  228  114    6  206       -1    T
# 12                1023   82   57  121  100  248   16   80   52       -1    R
# ...                ...  ...  ...  ...  ...  ...  ...  ...  ...      ...  ...
# 730507             520  179  161   27   31  197   80   81  249       -1    T
# 730508             885  128   52    9  122  191   12    4  163       -1    T
# 730510             768  229   71   70  105   46  188  248  128       -1    T
# 730513             520  228  142   46    5   41   67   31   93       -1    T
# 730514             768  227  118   48  187  220   18  186  136       -1    T
#
# [344733 rows x 11 columns]

# %%
df5.sample(20)
# Out:
#         CAN Identifier   D0   D1   D2   D3   D4   D5   D6   D7  anomaly Flag
# 712495             520    0   32    0    0   72   43   72   48        1    R
# 319756             520    0   32    0    1   71   49   71   51        1    R
# 579482             520  200  192  213  235  132  104  193  220       -1    T
# 623508            1023   76   35   46   15   54  218  195  154       -1    T
# 273083             768  114  171   40   64  234   65  180    2       -1    T
# 662619             768  145   93  118   71   43   84  114  128       -1    T
# 712704             520    0   32    0    2   71   54   71   59        1    R
# 34145             1023   78   57  119  100  254   16   80   52        1    R
# 631792             520  235  191  147  177   50  157   62  254       -1    T
# 153550             520    0   32    0    4    0    0    0    0        1    R
# 473902            1023  206  254   35  205   21  190  199  119       -1    T
# ...

# %%
df5[["anomaly"]].value_counts().reset_index()
# Out:
#    anomaly   count
# 0        1  373539
# 1       -1  356980

# %%
df5[(df5['anomaly'] == -1 )& (df5['Flag'] == "T" )].value_counts().reset_index()
#315938 anomaly and says anomaly found ddos in 1023 and 885 node becouse its too low (10000) if its grow to 30000 cant detect it!

# df5[(df5['new_class'] == "outlier" )& (df5['Flag'] == "T" )].reset_index()
# Out:
#         CAN Identifier   D0   D1   D2   D3   D4   D5   D6   D7  anomaly Flag  \
# 0                  520    0    1  187  130  203   11  165  141       -1    T
# 1                  768  170   32  109  136  250  197   66  174       -1    T
# 2                  768  170   19   49   55  134  202   75  157       -1    T
# 3                  768  170   21   39  117  218  115  128   68       -1    T
# 4                  768  170   22  175  207  147  139  121   19       -1    T
# ...                ...  ...  ...  ...  ...  ...  ...  ...  ...      ...  ...
# 276025             520  202  103   85  214   33   51  236   20       -1    T
# 276026             520  202  103  168   85   50  148   15   17       -1    T
# 276027             520  202  104  130   61  238  104  136  204       -1    T
# 276028             520  202  105   37  193  110    1  224  238       -1    T
# 276029            1023  254  251  213  207  175  228  254  181       -1    T
#
#         count
# 0           1
# ...

# %%
df5[(df5['anomaly'] == -1 )& (df5['Flag'] == "R" )].value_counts().reset_index()#39055  normal and says anomaly (FP)
# df5[(df5['new_class'] == "inlier" )& (df5['Flag'] == "R" )].value_counts().reset_index()#39055  normal and says anomaly (FP)
# Out:
#      CAN Identifier   D0   D1   D2   D3   D4   D5   D6  D7  anomaly Flag  \
# 0               520    0   32   15  255  192    0  192   0       -1    R
# 1               885   60  119   63   63   63    7    0   0       -1    R
# 2              1023  255   58  255  100    0   20  119  63       -1    R
# 3               885    0  119   63   63   63    7    0   0       -1    R
# 4              1023   84   56  125    0  240   20  119  63       -1    R
# ..              ...  ...  ...  ...  ...  ...  ...  ...  ..      ...  ...
# 123             520    0   32    0  223    0    0   64   0       -1    R
# 124             520    0   32    0  221   68  255   69   2       -1    R
# 125             520    0   32    0  221   64  241   65   0       -1    R
# 126             520    0   32    0  220   68  255   69   1       -1    R
# 127             520    0   32    1  144   65  255   66   1       -1    R
#
#      count
# 0       18
# 1        7
# 2        5
# 3        5
# 4        3
# ..     ...
# ...

# %%
df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "T" )].value_counts().reset_index()#80062 anomaly but says normal(most ddos attack) (ّFN) ddos on node 520 and 768
# df5[(df5['new_class'] == "inlier" )& (df5['Flag'] == "T" )].value_counts().reset_index()#80062 anomaly but says normal(most ddos attack) (ّFN) ddos on node 520 and 768
# Out:
#        CAN Identifier  D0  D1   D2   D3   D4   D5   D6   D7  anomaly Flag  \
# 0                 520   0   0    0    0    0    0    0    0        1    T
# 1                 768   0   0    0    0    0    0    0    0        1    T
# 2                 885   0   0    0    0    0    0    0    0        1    T
# 3                1023   0   0    0    0    0    0    0    0        1    T
# 4                 520   8  77  156  177  119  197   87  127        1    T
# ...               ...  ..  ..  ...  ...  ...  ...  ...  ...      ...  ...
# 39969             768  27  86  163  132   59   72  102  122        1    T
# 39970             768  27  88   58   37  190  194   45  150        1    T
# 39971             768  27  93  203  109  109   88  150   75        1    T
# 39972             768  27  95  109   62  132  198  205   59        1    T
# 39973             768  86  17   51  153   96   94   65  220        1    T
#
#        count
# 0      10000
# 1      10000
# 2      10000
# 3      10000
# ...

# %%
df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "R" )].value_counts().reset_index()#295464 its normal and says normal(TN)

# %%
tp=len(df5[(df5['anomaly'] == -1 )& (df5['Flag'] == "T" )].reset_index())
fp=len(df5[(df5['anomaly'] == -1 )& (df5['Flag'] == "R" )].reset_index())
fn=len(df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "T" )].reset_index())
tn=len(df5[(df5['anomaly'] == 1 )& (df5['Flag'] == "R" )].reset_index())
print('tp = ',tp,"fp = ",fp,"fn = ",fn,"tn = ",tn)
precision = tp / (tp + fp)

# Calculate recall
recall = tp / (tp + fn)

# Calculate F1 score
f1 = 2 * (precision * recall) / (precision + recall)

precision, recall, f1
# Out:
# tp =  276030 fp =  178 fn =  79970 tn =  334341
# (0.9993555581301049, 0.7753651685393258, 0.8732252676334371)

# %%
accuracy = (tp+tn)/(tp+tn+fn+fp)
accuracy
# Out:
# 0.8839307824983816
